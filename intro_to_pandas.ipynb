# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series(["Amy","Carl","Sam"])
series
# Out:
# 0     Amy
# 1    Carl
# 2     Sam
# dtype: object

# %%
maps = pd.Series(["Red","White","Green","Blue"])
assets = pd.Series(["Barrel","Tree","House","Character"])

# %%
prod_data = pd.DataFrame({"Maps":maps, "Assets":assets})
prod_data
# Out:
#     Maps     Assets
# 0    Red     Barrel
# 1  White       Tree
# 2  Green      House
# 3   Blue  Character

# %%
# !ls
# Out:
# LICENSE                     intro_to_pandas.ipynb
# README.md                   numpy_basics.ipynb
# city_lights_data_creator.py points.csv
# csv_data.py                 sentimentdataset.csv
# houdini_create_pts.py

# %%
sentiment_dataset = pd.read_csv("sentimentdataset.csv")

# %%
sentiment_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
sentiment_dataset.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %%
sentiment_dataset.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
sentiment_dataset["Text"]
# Out:
# 0       Enjoying a beautiful day at the park!        ...
# 1       Traffic was terrible this morning.           ...
# 2       Just finished an amazing workout! 💪          ...
# 3       Excited about the upcoming weekend getaway!  ...
# 4       Trying out a new recipe for dinner tonight.  ...
#                              ...
# 727    Collaborating on a science project that receiv...
# 728    Attending a surprise birthday party organized ...
# 729    Successfully fundraising for a school charity ...
# 730    Participating in a multicultural festival, cel...
# 731    Organizing a virtual talent show during challe...
# Name: Text, Length: 732, dtype: object

# %%
sentiment_dataset.index
# Out:
# RangeIndex(start=0, stop=732, step=1)

# %%
sentiment_dataset.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
sentiment_dataset["Retweets"].mean()
# Out:
# 21.508196721311474

# %%
sentiment_dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
sentiment_dataset.loc[3]
# Out:
# Unnamed: 0.1                                                    3
# Unnamed: 0                                                      3
# Text             Excited about the upcoming weekend getaway!  ...
# Sentiment                                              Positive
# Timestamp                                     2023-01-15 18:20:00
# User                                                AdventureX
# Platform                                                Facebook
# Hashtags                #Travel #Adventure
# Retweets                                                      8.0
# Likes                                                        15.0
# Country                                                 UK
# Year                                                         2023
# Month                                                           1
# Day                                                            15
# Hour                                                           18
# ...

# %%
sentiment_dataset.iloc[2]
# Out:
# Unnamed: 0.1                                                    2
# Unnamed: 0                                                      2
# Text             Just finished an amazing workout! 💪          ...
# Sentiment                                              Positive
# Timestamp                                     2023-01-15 15:45:00
# User                                                FitnessFan
# Platform                                               Instagram
# Hashtags                #Fitness #Workout
# Retweets                                                     20.0
# Likes                                                        40.0
# Country                                               USA
# Year                                                         2023
# Month                                                           1
# Day                                                            15
# Hour                                                           15
# ...

# %%
sentiment_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_dataset[sentiment_dataset["Retweets"] > 20.0]
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 5               5           5
# 8               8           8
# 10             10          10
# 13             13          13
# 18             18          18
# ..            ...         ...
# 726           727         731
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 5     Feeling grateful for the little things in lif...   Positive
# 8     Political discussions heating up on the timel...   Negative
# 10    Just published a new blog post. Check it out!...   Positive
# 13    New year, new fitness goals! 💪               ...   Positive
# 18    Attending a virtual conference on AI.        ...   Neutral
# ..                                                 ...          ...
# 726  Achieving a personal best in a track and field...       Happy
# ...

# %%
pd.crosstab(sentiment_dataset["Country"], sentiment_dataset["Retweets"])
# Out:
# Retweets             5.0   7.0   8.0   9.0   10.0  11.0  12.0  13.0  14.0  \
# Country
#  Australia              0     0     0     0     2     0     3     0     0
#  Australia              0     0     0     0     0     0     0     0     0
#  Australia              0     0     0     0     0     0     0     0     0
#  Australia              0     0     2     0     1     0     1     0     3
#  Australia              0     1     1     0     0     0     1     0     0
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
#  USA                    1     0     0     0     4     0     3     1     0
#  USA                    0     0     1     0     0     0     0     0     0
#  USA                    0     0     0     0     0     0     0     0     0
#  USA                    0     0     0     0     0     0     0     0     0
# USA                     0     0     0     0     0     0     0     0     0
#
# ...

# %%
sentiment_dataset.groupby(["Platform"]).sum()
# Out:
#              Unnamed: 0.1  Unnamed: 0  \
# Platform
#  Facebook           83211       83962
#  Instagram          95929       96782
#  Twitter            66419       66931
#  Twitter            22693       22975
#
#                                                           Text  \
# Platform
#  Facebook     Excited about the upcoming weekend getaway!  ...
#  Instagram    Just finished an amazing workout! 💪          ...
#  Twitter      Dancing through life with the exuberance of a...
#  Twitter      Enjoying a beautiful day at the park!        ...
#
#                                                      Sentiment  \
# Platform
#  Facebook     Positive   Positive   Neutral    Positive   P...
#  Instagram    Positive   Neutral    Positive   Positive   P...
#  Twitter      Zest  Proud  Compassionate  Inspired  Serenit...
#  Twitter      Positive   Negative   Positive   Negative   N...
#
#                                                      Timestamp  \
# Platform
# ...

# %%
sentiment_dataset["Retweets and Likes"] = sentiment_dataset["Retweets"] + sentiment_dataset["Likes"]

# %%
sentiment_dataset
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
sentiment_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_dataset["Retweets"] = sentiment_dataset["Retweets"].astype(np.int16)

# %%
sentiment_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_dataset.dtypes
# Out:
# Unnamed: 0.1            int64
# Unnamed: 0              int64
# Text                   object
# Sentiment              object
# Timestamp              object
# User                   object
# Platform               object
# Hashtags               object
# Retweets                int16
# Likes                 float64
# Country                object
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Retweets and Likes    float64
# dtype: object

# %%
sentiment_dataset["Hashtags"] = sentiment_dataset["Hashtags"].str.replace("#","")

# %%
sentiment_dataset.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                    Hashtags  Retweets  Likes       Country  \
# ...

# %%
sentiment_dataset[(sentiment_dataset["Retweets"] > 20) & (sentiment_dataset["Country"] == "USA")]
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 10             10          10
# 18             18          18
# 33             34          35
# 39             40          41
# 128           129         131
#
#                                                   Text        Sentiment  \
# 10    Just published a new blog post. Check it out!...       Positive
# 18    Attending a virtual conference on AI.        ...       Neutral
# 33    Feeling inspired after attending a workshop. ...       Positive
# 39    Excited about the upcoming gaming tournament....       Positive
# 128   Empowerment through learning and personal gro...   Empowerment
#
#                Timestamp               User     Platform  \
# 10   2023-01-17 15:15:00      BloggerX        Instagram
# 18   2023-01-20 11:30:00     TechConference    Facebook
# 33   2023-01-26 09:45:00   WorkshopAttendee   Instagram
# 39   2023-01-28 09:00:00   GamingEnthusiast   Instagram
# 128  2014-07-20 11:30:00   GrowthSeeker       Instagram
#
# ...

# %%
sentiment_dataset["Retweets"].plot()
# Out:
# <Axes: >

# %%
sentiment_dataset["Retweets"].hist()
# Out:
# <Axes: >

# %%
sentiment_dataset["Likes"].hist()
# Out:
# <Axes: >
